# %%
# ISAÍAS RIBEIRO - Telegram chat bot (25/11/21)
import telebot

# CHAVE_API = AQUI VOCÊ TEM QUE COLOCAR A CHAVE TOKEN, PARA VOCÊ CONSEGUIR ESTE TOKEN, ABRA O TELEGRAM! NA BARRA DE PESQUISA DO TELEGRAM E PESQUISE *botfather*,
# DEPOIS /newbot E ASSIM POR DIANTE....  

bot = telebot.TeleBot(CHAVE_API)

@bot.message_handler(commands=["pizza"]) # pizza
def pizza(mensagem):
    bot.send_message(mensagem.chat.id,"Saindo a pizza para a sua casa! Tempo de espera, 20 minutos.")


@bot.message_handler(commands=["hamburguer"]) # hamburgão
def hamburguer(mensagem):
    bot.send_message(mensagem.chat.id, "O hamburgão está sendo preparado! Você não vai se arrepender.... Tempo de espera: 30 minutos")


@bot.message_handler(commands=["salada"]) # salada
def pizza(mensagem):
    bot.send_message(mensagem.chat.id, "A salada acabou, por favor acesse o menu novamente /iniciar")

# OPÇÕES 1 ATÉ A 3 -----------------------------
@bot.message_handler(commands=["opcao1"]) # O P C A O - 1
def opcao1(mensagem):
    texto = """
    /pizza Pizza
    /hamburguer Hamburguer
    /salada Salada"""
    bot.send_message(mensagem.chat.id,texto)

@bot.message_handler(commands=["opcao2"]) # O P C A O -- 2
def opcao2(mensagem):
    bot.send_message(mensagem.chat.id, "Para reclamar sobre o BOT, envie um e-mail para isaias.marcelino3@outlook.com")

@bot.message_handler(commands=["opcao3"]) # O P C A O --- 3
def opcao3(mensagem):
    bot.send_message(mensagem.chat.id, "Valeu, o Isaías mandou um abraço de volta!")
# OPÇÕES 1 ATÉ A 3 -----------------------------------

def verificar(mensagem):
    return True
@bot.message_handler(func=verificar)
def responder(mensagem):
    texto = """
    Escolha uma opção para continuar (Clique no item):
    /opcao1 - Fazer um pedido
    /opcao2 - Reclamar do bot
    /opcao3 - Mandar um abraço para o Isaías
Responder qualquer outra coisa não irá funcionar, clique em uma das opções"""
    bot.reply_to(mensagem , texto)

bot.polling()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# ...
